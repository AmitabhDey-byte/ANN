# %% [markdown]
# <a href="https://colab.research.google.com/github/AmitabhDey-byte/ANN/blob/main/Qwen2_5_3B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="Qwen/Qwen2.5-3B")
messages = [
    {"role": "user", "content": "Tell me the upcoming fifa match"},
]
pipe(messages)
# Out:
# config.json:   0%|          | 0.00/683 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/35.6k [00:00<?, ?B/s]
# ...
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/138 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.23k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipykernel_575/1163554053.py in <cell line: 0>()
#       2 from transformers import pipeline
#       3
# ----> 4 pipe = pipeline("text-generation", model="Qwen/Qwen2.5-3B")
#       5 messages = [
#       6     {"role": "user", "content": "Tell me the upcoming fifa match"},
#
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-3B")
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen2.5-3B")
messages = [
    {"role": "user", "content": "Tell me the upcoming fifa match"},
]
inputs = tokenizer.apply_chat_template(
	messages,
	add_generation_prompt=True,
	tokenize=True,
	return_dict=True,
	return_tensors="pt",
).to(model.device)

outputs = model.generate(**inputs, max_new_tokens=40)
print(tokenizer.decode(outputs[0][inputs["input_ids"].shape[-1]:]))
